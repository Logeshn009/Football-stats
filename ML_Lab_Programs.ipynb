# %% [markdown]
# <a href="https://colab.research.google.com/github/Logeshn009/Football-stats/blob/main/ML_Lab_Programs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lab 2 EDA

# %% [markdown]
# #Uploading the file

# %%
# uploaded dataset

from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-11333911-2b1f-4a31-9b26-711f10d934fb" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-11333911-2b1f-4a31-9b26-711f10d934fb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving isl_player_final.csv to isl_player_final.csv

# %% [markdown]
# # Importing needed packages

# %%
#importing needed packages

import pandas as pd
import numpy as ny
import matplotlib.pyplot as plt
import seaborn as sns #python data visualization library based on matplotib
# %matplotlib inline

# %% [markdown]
# # Reading the csv file and performing 11 essential EDA code blocks

# %%
# reading the csv file

data = pd.read_csv('isl_player_final.csv')

# %% [markdown]
# **11 Essential code blocks for EDA **

# %%
#1 .shape attribute (dimensions) of the dataframe - which gives the overall structure of the data

data.shape #output (563, 93) - (rows, cols)

#2 data types of the various columns

data.dtypes

# %%
#3 Display a few rows

data.head()
data.tail()
data.sample(5)

# %%
#4 plot each numeric feature

data.hist(figsize=(50,50), xrot=45)
plt.show()

# %%
#5 summary stats of the numerical features 

data.describe()
# Out:
#           tour_id             id   jersey_no  position_id      team_id  \
# count  563.000000     563.000000  563.000000   563.000000   563.000000
# mean   177.349911   36417.937833   18.966252     2.287744   875.301954
# std     26.921464   28532.321528   13.855916     1.024074   463.425680
# min    148.000000     459.000000    1.000000     1.000000   496.000000
# 25%    148.000000   19083.500000    9.000000     1.000000   504.000000
# 50%    202.000000   31848.000000   17.000000     2.000000   506.000000
# 75%    202.000000   38918.000000   26.000000     3.000000  1159.000000
# max    202.000000  145060.000000   99.000000     4.000000  1874.000000
#
#        is_started  is_onbench  is_goalkeeper  is_substitute  minutes_played  \
# count  563.000000  563.000000     563.000000     563.000000      563.000000
# mean     8.188277    6.055062       0.761989       4.642984      736.090586
# std      6.973774    4.557910       3.387255       4.451246      610.039991
# ...

# %%
#6 summary stats of the categorical features

data.describe(include='object')
# Out:
#        tour_name             name       short_name    position position_short  \
# count        563              563              563         563            563
# unique         2              399              400           4              4
# top         ISL7  Abhishek Halder  Shubham Sarangi  Midfielder             MF
# freq         306                2                2         222            222
#
#            team_name team_short_name country_name         dob player_foot
# count            563             563          563         399         310
# unique            12              13           43         215           6
# top     Bengaluru FC             BFC        India  0000-00-00       Right
# freq              59              59          408          28         175

# %%
#7 plottling each categorical feature

for column in data.select_dtypes(include='object'):
  if data[column].nunique() < 10:
    sns.countplot(y=column, data=data)
    plt.show()

# %%
#8 segement the target variable by categorical features

for column in data.select_dtypes(include='object'):
  if data[column].nunique() < 10:
    sns.boxplot(y=column, x='minutes_played', data=data)
    plt.show()

# %%
#9 group numeric features by each categorical feature

for column in data.select_dtypes(include='object'):
    if data[column].nunique() < 10:
        display(data.groupby(column).mean())
# Out:
#            tour_id            id  jersey_no  position_id     team_id  \
# tour_name
# ISL6         148.0  30609.338521  17.809339     2.256809  790.782101
# ISL7         202.0  41296.401961  19.937908     2.313725  946.287582
#
#            is_started  is_onbench  is_goalkeeper  is_substitute  \
# tour_name
# ISL6         8.101167    5.167315       0.750973       4.019455
# ISL7         8.261438    6.800654       0.771242       5.166667
#
#            minutes_played  bonus_points  injury_minutes_played  \
# tour_name
# ISL6           726.568093           0.0              37.961089
# ISL7           744.088235           0.0              51.535948
#
#            actual_minutes_played  goaltenders  events.goals  events.own_goals  \
# tour_name
# ISL6                  771.579767          0.0      1.105058          0.031128
# ISL7                  795.375817          0.0      0.937908          0.035948
#
#            events.assists  events.key_passes  events.chances_created  \
# tour_name
# ...

# %%
#10 Correlations matrix for the different numerical features

corrs = data.corr()
corrs
# Out:
#                                           tour_id        id  jersey_no  \
# tour_id                                  1.000000  0.186735   0.076587
# id                                       0.186735  1.000000   0.111667
# jersey_no                                0.076587  0.111667   1.000000
# position_id                              0.027708 -0.091372  -0.029034
# team_id                                  0.167290  0.011535  -0.007967
# ...                                           ...       ...        ...
# goaltenders.penalty_kicks.shots_faced   -0.009405 -0.115503  -0.062401
# goaltenders.penalty_kicks.goals_allowed -0.020247 -0.116424  -0.078527
# goaltenders.penalty_kicks.saves          0.011320 -0.068110   0.001686
# country_id                              -0.028225 -0.027900  -0.094504
# height                                  -0.062670 -0.339102  -0.116012
#
#                                          position_id   team_id  is_started  \
# ...

# %%
data.boxplot(column=['minutes_played'])
plt.show()

# %%
#11 check for missing values in any column

data.isnull().sum()
# Out:
# tour_id           0
# tour_name         0
# id                0
# jersey_no         0
# name              0
#                ...
# country_id        0
# country_name      0
# dob             164
# player_foot     253
# height          184
# Length: 93, dtype: int64

# %%
names = data["position"].value_counts().keys()
counts = data["position"].value_counts().values
plt.subplots(figsize=(8, 5))
plt.bar(names, counts, color="blue")
plt.xlabel("class names")
plt.ylabel("Frequency")
plt.title("Distribtuion of class")
plt.show()

# %% [markdown]
# # Lab 2 Linear Regression

# %%
# returns the number of missing values in the data set

uniqueCounts = data.nunique();
print("Unique count across columns:")
print(uniqueCounts);
# Out:
# Unique count across columns:
# tour_id           2
# tour_name         2
# id              395
# jersey_no        56
# name            399
#                ...
# country_id       43
# country_name     43
# dob             215
# player_foot       6
# height           31
# Length: 93, dtype: int64

# %%
df_reduced = data.fillna(data.mean())
df_reduced

# %%
df_reduced.isnull().sum()
# Out:
# tour_id           0
# tour_name         0
# id                0
# jersey_no         0
# name              0
#                ...
# country_id        0
# country_name      0
# dob             164
# player_foot     253
# height            0
# Length: 93, dtype: int64

# %%
#importing needed packages

import pandas as pd
import numpy as ny
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from sklearn.linear_model import LinearRegression
from numpy.linalg import inv,lstsq
from numpy import dot, transpose

# %%
data_set = pd.read_csv('isl_player_final.csv')
data_set

# %%
dset = data_set.copy()
dset.head()

# %%
dset.columns

# %%
x = dset.fillna(0)['events.shots_on_target']
y = dset.fillna(0)['events.goals']
x = x.values.reshape(len(x), 1)
y = y.values.reshape(len(y), 1)
X_train = x[:-500]
X_test = x[-500:]
Y_train = y[:-500]
Y_test = y[-500:]
model = LinearRegression()
model.fit(X_test,Y_test)
plt.figure()
plt.xlabel('Goals scored')
plt.ylabel('Goals scoredShots on Target')
plt.plot(X_test,Y_test,'.')
plt.plot(X_test,model.predict(X_test),'--')
plt.axis([0,35,0,20])
plt.grid(True)
print ("Predicted weight = ",model.predict([[5]]))
plt.show()
# Out:
# Predicted weight =  [[1.70378525]]

# %%
plt.scatter(X_test,Y_test)
plt.show()

# %%
# Linear regression 

# The first step is to load the dataset

from google.colab import files

uploaded = files.upload()

# data will be loaded using Python Pandas
# It will be loaded into a structure known as a Panda Data Frame, which allows for each manipulation of the rows and columns.
# Out:
#      <input type="file" id="files-14e97909-5935-4d14-b546-6a5a9ab5b7cb" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-14e97909-5935-4d14-b546-6a5a9ab5b7cb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# # STEPS TO FOLLOW >>>
#
# We create two arrays: Y (shots_on_target) and X (goals_scored).
# Intuitively we’d expect to find some correlation between shots on target and goals scored.
# The data will be split into a trainining and test set. Once we have the test data, we can find a best fit line and make predictions

# %%
# Importing the necessary packages

import matplotlib
import matplotlib.pyplot as plt
import numpy as ny
from sklearn import datasets, linear_model
import pandas as pd

# %%
# Load CSV and columns

df = pd.read_csv("isl.csv")

# %%
# Setting the x and y variables

X = df['goals']
Y = df['shots_on_target']

# %%
X=X.values.reshape(len(X),1)
Y=Y.values.reshape(len(Y),1)

# print(X.reshape(len(X),1))

# %%
# Split the data into training/testing sets

X_train = X[:-250]
X_test = X[-250:]

# The syntax is x[row_index,column_index]
# you can also specify a range of row values as per need in row_index also 
# eg:1:13 extracts first 13 rows along with whatever specified in column
# Python also allows you to index from the end of the list using a negative number, where [-1] returns the last element.

# For Example >>>>>

#  0    1    2    3    4    5    6    7    8
#   ↓    ↓    ↓    ↓    ↓    ↓    ↓    ↓    ↓
# ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i']
#   ↑    ↑    ↑    ↑    ↑    ↑    ↑    ↑    ↑
#  -9   -8   -7   -6   -5   -4   -3   -2   -1

# %%
# Split the targets into training/testing sets

Y_train = Y[:-250]
Y_test = Y[-250:]

# %%
# Plot outputs
# Plotting the test data

plt.scatter(X_test, Y_test,  color='black')
plt.title('Test Data')
plt.xlabel('Goals Scored')
plt.ylabel('Shots on Target')
plt.xticks(())
plt.yticks(())

plt.show()

# %%
# We have created the two datasets and have the test data on the screen. We can continue to create the best fit line


# Create linear regression object
model = linear_model.LinearRegression()

# Train the model using the training sets
model.fit(X_train, Y_train)

# Plot outputs
plt.scatter(X_test, Y_test,  color='black')
plt.plot(X_test, model.predict(X_test), color='red',linewidth=3)
plt.title('Linear Regression')
plt.xlabel('Goals Scored')
plt.ylabel('Shots on Target')
plt.show()
print ("Predicted weight = ",model.predict([[5]]))

# %% [markdown]
# # Lab 2 Multiple Regression

# %%
#Extracting Independent and dependent Variable  
x = df['events.goals']
y = df['events.shots_on_target']

# %% [markdown]
# # Lab 3 KNN

# %% [markdown]
# Importing essential packages

# %%
import numpy as ny
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Uploading the datasets

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-c033827b-5372-4040-8a2d-578f9c497533" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c033827b-5372-4040-8a2d-578f9c497533">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving isl_player_final.csv to isl_player_final.csv

# %%
import io
dataset = pd.read_csv(io.BytesIO(uploaded['isl_player_final.csv']))

# %% [markdown]
# Finding the null values

# %%
dataset.position.unique()
# Out:
# array(['Forward', 'Midfielder', 'Defender', 'Goalkeeper'], dtype=object)

# %%
dataset.name.unique()

# %%
dataset.country_name.unique()

# %% [markdown]
# Removing the null values

# %%
# Removing null values

dataset.isnull()

# %% [markdown]
# Replacing the null values with zero

# %%
# Replacing null values with zero

dataset=dataset.fillna(0)
dataset.head()

# %% [markdown]
# Selecting the needed columns from the dataset

# %%
position = dataset.loc[:, ["goals", "shots_on_target", "fouls_committed", "successful_tackles", "position"]]

# %%
position.isnull()

# %%
position = position.fillna(0)
position.head()

# %% [markdown]
# To split the datasets into attributes and labels

# %%
# x variable contains first four attributes
X = position.iloc[:, :-1].values

# y variable contains the label
Y = position.iloc[:, 4].values

# %% [markdown]
# Dividing the dataset into training and test sets

# %%
# importing test train model
# importing the train_test_split class from the sklearn.model_selecition library

from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.20)

# %%
# importing the StandardScalar class from the sklearn.preprocessing library
# scaling normalization

from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# # For K = 5

# %%
# import the KNeighborsClassifier class from the sklearn.neighbors library

from sklearn.neighbors import KNeighborsClassifier
classifier = KNeighborsClassifier(n_neighbors = 5, metric = 'euclidean')
classifier.fit(X_train, Y_train)
# Out:
# KNeighborsClassifier(metric='euclidean')

# %%
# prediction of our data

Y_pred = classifier.predict(X_test)

# %%
# confusion_matrix and classification_report methods of the sklearn.metrics are used
# importing the classes classification_report, confusion_matrix from th sklearn.metrics library

from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(Y_test, Y_pred))
print(classification_report(Y_test, Y_pred))

# For evaluating an algorithm, confusion matrix, precision, recall and f1 score are the most commonly used metrics.
# Out:
# [[22  7  0  6]
#  [ 1  7  1  5]
#  [ 0 11  0  1]
#  [25  8  2 17]]
#               precision    recall  f1-score   support
#
#     Defender       0.46      0.63      0.53        35
#      Forward       0.21      0.50      0.30        14
#   Goalkeeper       0.00      0.00      0.00        12
#   Midfielder       0.59      0.33      0.42        52
#
#     accuracy                           0.41       113
#    macro avg       0.31      0.36      0.31       113
# weighted avg       0.44      0.41      0.39       113

# %%
error = []

# Calculating error for K values between 1 and 40
for i in range(1, 40):
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(X_train, Y_train)
    pred_i = knn.predict(X_test)
    error.append(ny.mean(pred_i != Y_test))

# %%
plt.figure(figsize=(12, 6))
plt.plot(range(1, 40), error, color='red', linestyle='dashed', marker='o',
         markerfacecolor='blue', markersize=10)
plt.title('Error Rate K Value')
plt.xlabel('K Value')
plt.ylabel('Mean Error')
# Out:
# Text(0, 0.5, 'Mean Error')

# %% [markdown]
# # For K = 4

# %%
# import the KNeighborsClassifier class from the sklearn.neighbors library

from sklearn.neighbors import KNeighborsClassifier
classifier = KNeighborsClassifier(n_neighbors = 4, metric = 'manhattan')
classifier.fit(X_train, Y_train)
# Out:
# KNeighborsClassifier(n_neighbors=4)

# %%
# prediction of our data

Y_pred = classifier.predict(X_test)

# %%
# confusion_matrix and classification_report methods of the sklearn.metrics are used
# importing the classes classification_report, confusion_matrix from th sklearn.metrics library

from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(Y_test, Y_pred))
print(classification_report(Y_test, Y_pred))

# For evaluating an algorithm, confusion matrix, precision, recall and f1 score are the most commonly used metrics.
# Out:
# [[22  7  0  6]
#  [ 1  7  1  5]
#  [ 0 11  0  1]
#  [29  9  1 13]]
#               precision    recall  f1-score   support
#
#     Defender       0.42      0.63      0.51        35
#      Forward       0.21      0.50      0.29        14
#   Goalkeeper       0.00      0.00      0.00        12
#   Midfielder       0.52      0.25      0.34        52
#
#     accuracy                           0.37       113
#    macro avg       0.29      0.34      0.28       113
# weighted avg       0.40      0.37      0.35       113

# %% [markdown]
# # For K = 3

# %%
# import the KNeighborsClassifier class from the sklearn.neighbors library

from sklearn.neighbors import KNeighborsClassifier
classifier = KNeighborsClassifier(n_neighbors = 3, metric = 'minkowski')
classifier.fit(X_train, Y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
# prediction of our data

Y_pred = classifier.predict(X_test)

# %%
# confusion_matrix and classification_report methods of the sklearn.metrics are used
# importing the classes classification_report, confusion_matrix from th sklearn.metrics library

from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(Y_test, Y_pred))
print(classification_report(Y_test, Y_pred))

# For evaluating an algorithm, confusion matrix, precision, recall and f1 score are the most commonly used metrics.
# Out:
# [[19  7  0  9]
#  [ 2  6  1  5]
#  [ 0 11  0  1]
#  [30  7  1 14]]
#               precision    recall  f1-score   support
#
#     Defender       0.37      0.54      0.44        35
#      Forward       0.19      0.43      0.27        14
#   Goalkeeper       0.00      0.00      0.00        12
#   Midfielder       0.48      0.27      0.35        52
#
#     accuracy                           0.35       113
#    macro avg       0.26      0.31      0.26       113
# weighted avg       0.36      0.35      0.33       113

# %% [markdown]
# # For K = 2

# %%
# import the KNeighborsClassifier class from the sklearn.neighbors library

from sklearn.neighbors import KNeighborsClassifier
classifier = KNeighborsClassifier(n_neighbors = 2)
classifier.fit(X_train, Y_train)
# Out:
# KNeighborsClassifier(n_neighbors=2)

# %%
# prediction of our data

Y_pred = classifier.predict(X_test)

# %%
# confusion_matrix and classification_report methods of the sklearn.metrics are used
# importing the classes classification_report, confusion_matrix from th sklearn.metrics library

from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(Y_test, Y_pred))
print(classification_report(Y_test, Y_pred))

# For evaluating an algorithm, confusion matrix, precision, recall and f1 score are the most commonly used metrics.
# Out:
# [[24  9  0  2]
#  [ 2  8  1  3]
#  [ 0 11  0  1]
#  [35  9  1  7]]
#               precision    recall  f1-score   support
#
#     Defender       0.39      0.69      0.50        35
#      Forward       0.22      0.57      0.31        14
#   Goalkeeper       0.00      0.00      0.00        12
#   Midfielder       0.54      0.13      0.22        52
#
#     accuracy                           0.35       113
#    macro avg       0.29      0.35      0.26       113
# weighted avg       0.40      0.35      0.29       113

# %% [markdown]
# # For K = 1

# %%
# import the KNeighborsClassifier class from the sklearn.neighbors library

from sklearn.neighbors import KNeighborsClassifier
classifier = KNeighborsClassifier(n_neighbors = 1)
classifier.fit(X_train, Y_train)
# Out:
# KNeighborsClassifier(n_neighbors=1)

# %%
# prediction of our data

Y_pred = classifier.predict(X_test)

# %%
# confusion_matrix and classification_report methods of the sklearn.metrics are used
# importing the classes classification_report, confusion_matrix from th sklearn.metrics library

from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(Y_test, Y_pred))
print(classification_report(Y_test, Y_pred))

# For evaluating an algorithm, confusion matrix, precision, recall and f1 score are the most commonly used metrics.
# Out:
# [[15  3  0 17]
#  [ 2  7  1  4]
#  [ 0  0  0 12]
#  [19 13  1 19]]
#               precision    recall  f1-score   support
#
#     Defender       0.42      0.43      0.42        35
#      Forward       0.30      0.50      0.38        14
#   Goalkeeper       0.00      0.00      0.00        12
#   Midfielder       0.37      0.37      0.37        52
#
#     accuracy                           0.36       113
#    macro avg       0.27      0.32      0.29       113
# weighted avg       0.33      0.36      0.35       113

# %% [markdown]
# # Lab 4 K-Means

# %%
# import essential packages

import numpy as ny
import pandas as pd
import seaborn as sns
import sklearn
import matplotlib.pyplot as plt
sns.set()
from sklearn.cluster import KMeans

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-7616c060-90d9-44bb-a03c-77b0d3d34271" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7616c060-90d9-44bb-a03c-77b0d3d34271">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving isl.csv to isl.csv

# %%
import io
data = pd.read_csv(io.BytesIO(uploaded['isl.csv']))

# %%
plt.scatter(data['events.shots_on_target'], data['events.goals'])
plt.ylabel('Goals Scored')
plt.xlabel('Shots on Target')
plt.show()
# plot shows the actual mins played vs good passes

# %%
X = data[['events.goals', 'events.shots_on_target' ]]

# %%
kmeans = KMeans(2)
kmeans.fit(X)
# Out:
# KMeans(n_clusters=2)

# %% [markdown]
# Clustering result

# %%
clusters = X.copy()
clusters['cluster_pred'] = kmeans.fit_predict(X)

# %% [markdown]
# Plot

# %%
plt.scatter(clusters['events.goals'], clusters['events.shots_on_target'], c = clusters['cluster_pred'], cmap = 'rainbow')
plt.xlabel('Goals Scored')
plt.ylabel('Shots on Target')
plt.show()

# %% [markdown]
# Standardizing the variables

# %%
from sklearn import preprocessing
x_scaled = preprocessing.scale(X)
x_scaled
# Out:
# array([[ 1.29868955,  1.14895681],
#        [ 0.86373285,  0.95347096],
#        [ 2.16860296,  1.34444266],
#        ...,
#        [-0.00618056, -0.21944415],
#        [-0.44113726, -0.61041586],
#        [-0.44113726, -0.41493001]])

# %% [markdown]
# Elbow method

# %%
# !pip3 install KMeans
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
wcss=[]
for i in range(1,7):
  kmeans = KMeans(i)
  kmeans.fit(x_scaled)
  wcss_iter = kmeans.inertia_
  wcss.append(wcss_iter)


number_clusters = range(1,7)
plt.plot(number_clusters,wcss)
plt.title('The Elbow title')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
# Out:
# Text(0, 0.5, 'WCSS')

# %%
kmeans_new = KMeans(4)
kmeans.fit(x_scaled)
cluster_new = x.copy()
cluster_new['cluster_pred'] = kmeans_new.fit_predict(x_scaled)
cluster_new
# Out:
#      tour_id tour_name      id  jersey_no                            name  \
# 0        148      ISL6    1514          3                    Asamoah Gyan
# 1        148      ISL6    2475         26            Deshorn Dwayne Brown
# 2        148      ISL6    2900          9                  Amine Chermiti
# 3        148      ISL6    3753          7           Francisco Medina Luna
# 4        148      ISL6    3809          4              Rafael Lopez Gomez
# ..       ...       ...     ...        ...                             ...
# 558      202      ISL7  144517          6  Hernan Daniel Santana Trujillo
# 559      202      ISL7  144593          2                   Scott Neville
# 560      202      ISL7  144594          4                      Daniel Fox
# 561      202      ISL7  144804         30          Ningombam Engson Singh
# 562      202      ISL7  145060         44              Haobam Tomba Singh
#
#              short_name  position_id    position position_short  team_id  ...  \
# ...

# %% [markdown]
# Plotting the new cluster

# %%
plt.scatter( cluster_new['events.goals'], cluster_new['events.shots_on_target'], c = cluster_new['cluster_pred'], cmap = 'rainbow')
plt.xlabel('Goals Scored')
plt.ylabel('Shots on Target')
plt.show()

# %% [markdown]
# # Analysis (The final step):
# Through the given figure following things can be interpreted:
# 1. The purple dots are the football players who have less shots on target and less goals. (0-1) -> goals and (0-4) -> shots_on_target
#
# 2. The red dots are the football players with few shots on target and scored few goals. (0-3) -> goals and (0-4) -> shots_on_target

# %% [markdown]
# # Lab 5 Hierarchical Clustering

# %%
import numpy as ny
import matplotlib.pyplot as plt
from scipy.cluster.hierarchy import dendrogram, linkage
from sklearn.cluster import AgglomerativeClustering

# %%
x = data.iloc[20:, [21, 22]].values

# %%
import scipy.cluster.hierarchy as shc  
dendro = shc.dendrogram(shc.linkage(x, method="ward"))  
plt.title("Dendrogrma Plot")  
plt.ylabel("Euclidean Distances")  
plt.xlabel("Players")  
plt.show()

# %%
#training the hierarchical model on dataset  
from sklearn.cluster import AgglomerativeClustering  
hc= AgglomerativeClustering(n_clusters=5, affinity='euclidean', linkage='ward')  
y_pred= hc.fit_predict(x)

# %%
#visulaizing the clusters  
plt.scatter(x[y_pred == 0, 0], x[y_pred == 0, 1], s = 100, c = 'blue', label = 'Cluster 1')  
plt.scatter(x[y_pred == 1, 0], x[y_pred == 1, 1], s = 100, c = 'green', label = 'Cluster 2')  
plt.scatter(x[y_pred== 2, 0], x[y_pred == 2, 1], s = 100, c = 'red', label = 'Cluster 3')  
plt.scatter(x[y_pred == 3, 0], x[y_pred == 3, 1], s = 100, c = 'cyan', label = 'Cluster 4')  
plt.scatter(x[y_pred == 4, 0], x[y_pred == 4, 1], s = 100, c = 'magenta', label = 'Cluster 5')  
plt.title('Clusters of Players')  
plt.xlabel('Goals Scored')  
plt.ylabel('Goals Scored (own)')  
plt.legend()  
plt.show()

# %% [markdown]
# # Lab 6 Decision tree algorithm

# %% [markdown]
# A Decision Tree is a supervised Machine learning algorithm. It is used in both classification and regression algorithms. A decision tree consists of the root nodes, children nodes, and leaf nodes.

# %%
# uploaded dataset

from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-879aec9a-ea08-461c-b0d5-150339b7608a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-879aec9a-ea08-461c-b0d5-150339b7608a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving isl_player_final.csv to isl_player_final.csv

# %%
#importing needed packages

import pandas as pd
import numpy as ny
import matplotlib.pyplot as plt
import seaborn as sns #python data visualization library based on matplotib
# %matplotlib inline

# %%
# reading the csv file

dataset = pd.read_csv('isl_player_final.csv')

# %%
# Removing null values

dataset.isnull()
# Out:
#      tour_id  tour_name     id  jersey_no   name  short_name  position_id  \
# 0      False      False  False      False  False       False        False
# 1      False      False  False      False  False       False        False
# 2      False      False  False      False  False       False        False
# 3      False      False  False      False  False       False        False
# 4      False      False  False      False  False       False        False
# ..       ...        ...    ...        ...    ...         ...          ...
# 558    False      False  False      False  False       False        False
# 559    False      False  False      False  False       False        False
# 560    False      False  False      False  False       False        False
# 561    False      False  False      False  False       False        False
# 562    False      False  False      False  False       False        False
#
#      position  position_short  team_id  ...  goaltenders.catches  \
# ...

# %%
# Replacing null values with zero

dataset_new=dataset.fillna(0)
dataset_new
# Out:
#      tour_id tour_name      id  jersey_no                            name  \
# 0        148      ISL6    1514          3                    Asamoah Gyan
# 1        148      ISL6    2475         26            Deshorn Dwayne Brown
# 2        148      ISL6    2900          9                  Amine Chermiti
# 3        148      ISL6    3753          7           Francisco Medina Luna
# 4        148      ISL6    3809          4              Rafael Lopez Gomez
# ..       ...       ...     ...        ...                             ...
# 558      202      ISL7  144517          6  Hernan Daniel Santana Trujillo
# 559      202      ISL7  144593          2                   Scott Neville
# 560      202      ISL7  144594          4                      Daniel Fox
# 561      202      ISL7  144804         30          Ningombam Engson Singh
# 562      202      ISL7  145060         44              Haobam Tomba Singh
#
#              short_name  position_id    position position_short  team_id  ...  \
# ...

# %% [markdown]
# # Lab 7 Logistic Regression classification algorithm

# %% [markdown]
# # Lab 8 Support Vector Machine

# %%
# uploaded dataset

from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-62561926-8a68-48f2-b01f-8083cfd5d1c6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-62561926-8a68-48f2-b01f-8083cfd5d1c6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#importing needed packages

import pandas as pd
import numpy as ny
import matplotlib.pyplot as plt
import seaborn as sns #python data visualization library based on matplotib
# %matplotlib inline

# %%
# reading the csv file

dataset = pd.read_csv('isl_player_final.csv')

# %%
# Removing null values

dataset.isnull()
# Out:
#      tour_id  tour_name     id  jersey_no   name  short_name  position_id  \
# 0      False      False  False      False  False       False        False
# 1      False      False  False      False  False       False        False
# 2      False      False  False      False  False       False        False
# 3      False      False  False      False  False       False        False
# 4      False      False  False      False  False       False        False
# ..       ...        ...    ...        ...    ...         ...          ...
# 558    False      False  False      False  False       False        False
# 559    False      False  False      False  False       False        False
# 560    False      False  False      False  False       False        False
# 561    False      False  False      False  False       False        False
# 562    False      False  False      False  False       False        False
#
#      position  position_short  team_id  ...  goaltenders.catches  \
# ...

# %%
# Replacing null values with zero

dataset_new=dataset.fillna(0)
dataset_new
# Out:
#      tour_id tour_name      id  jersey_no                            name  \
# 0        148      ISL6    1514          3                    Asamoah Gyan
# 1        148      ISL6    2475         26            Deshorn Dwayne Brown
# 2        148      ISL6    2900          9                  Amine Chermiti
# 3        148      ISL6    3753          7           Francisco Medina Luna
# 4        148      ISL6    3809          4              Rafael Lopez Gomez
# ..       ...       ...     ...        ...                             ...
# 558      202      ISL7  144517          6  Hernan Daniel Santana Trujillo
# 559      202      ISL7  144593          2                   Scott Neville
# 560      202      ISL7  144594          4                      Daniel Fox
# 561      202      ISL7  144804         30          Ningombam Engson Singh
# 562      202      ISL7  145060         44              Haobam Tomba Singh
#
#              short_name  position_id    position position_short  team_id  ...  \
# ...

# %%
# splitting the dataframes

df3 = dataset_new['events.key_passes']
df2 = dataset_new['shots_on_target']
df1 = dataset_new['name']
df4 = dataset_new['goals']

frames = pd.concat([df1, df2, df3, df4], axis=1).reindex(df1.index)
frames
# Out:
#                                name  shots_on_target  events.key_passes  goals
# 0                      Asamoah Gyan                9                  9      4
# 1              Deshorn Dwayne Brown                8                  3      3
# 2                    Amine Chermiti               10                 16      6
# 3             Francisco Medina Luna                7                  7      1
# 4                Rafael Lopez Gomez                0                  3      0
# ..                              ...              ...                ...    ...
# 558  Hernan Daniel Santana Trujillo                6                  8      2
# 559                   Scott Neville                3                  5      1
# 560                      Daniel Fox                2                  6      1
# 561          Ningombam Engson Singh                0                  0      0
# 562              Haobam Tomba Singh                1                  0      0
#
# [563 rows x 4 columns]

# %%
# Converting the non-zero data to 1 goals column

from pandas import DataFrame

df_goals = DataFrame(df4, columns =['goals'])
df_goals['Scored goals or not'] = df_goals['goals'].apply(lambda x: 1 if x >= 1 else 0)
df_goals
# Out:
#      goals  Scored goals or not
# 0        4                    1
# 1        3                    1
# 2        6                    1
# 3        1                    1
# 4        0                    0
# ..     ...                  ...
# 558      2                    1
# 559      1                    1
# 560      1                    1
# 561      0                    0
# 562      0                    0
#
# [563 rows x 2 columns]

# %%
# new table

frames = pd.concat([df2, df3, df_goals, df1], axis=1).reindex(df1.index)
frames
# Out:
#      shots_on_target  events.key_passes  goals  Scored goals or not  \
# 0                  9                  9      4                    1
# 1                  8                  3      3                    1
# 2                 10                 16      6                    1
# 3                  7                  7      1                    1
# 4                  0                  3      0                    0
# ..               ...                ...    ...                  ...
# 558                6                  8      2                    1
# 559                3                  5      1                    1
# 560                2                  6      1                    1
# 561                0                  0      0                    0
# 562                1                  0      0                    0
#
#                                name
# 0                      Asamoah Gyan
# 1              Deshorn Dwayne Brown
# 2                    Amine Chermiti
# ...

# %%
# splitting the dataset x and y

x = frames.iloc[:, [0,1]].values
y = frames.iloc[:, 3].values
y

# %%
# Splitting the dataset into training and test set

from sklearn.model_selection import train_test_split  
x_train, x_test, y_train, y_test= train_test_split(x, y, test_size= 0.25, random_state=0) 

#feature Scaling  
from sklearn.preprocessing import StandardScaler    
st_x= StandardScaler()    
x_train= st_x.fit_transform(x_train)    
x_test= st_x.transform(x_test)

# %% [markdown]
# # Support vector classifier - Linear

# %%
from sklearn.svm import SVC   
classifier = SVC(kernel='linear', random_state=0)  
classifier.fit(x_train, y_train)
# Out:
# SVC(kernel='linear', random_state=0)

# %%
# Predicting the test set result  

y_pred= classifier.predict(x_test)

# %%
# Creating the Confusion matrix

from sklearn.metrics import confusion_matrix  
cm= confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[93,  7],
#        [10, 31]])

# %%
from matplotlib.colors import ListedColormap  
x_set, y_set = x_train, y_train  
x1, x2 = ny.meshgrid(ny.arange(start = x_set[:, 0].min() - 1, stop = x_set[:, 0].max() + 1, step  =0.01), ny.arange(start = x_set[:, 1].min() - 1, stop = x_set[:, 1].max() + 1, step = 0.01))  
plt.contourf(x1, x2, classifier.predict(ny.array([x1.ravel(), x2.ravel()]).T).reshape(x1.shape), alpha = 0.75, cmap = ListedColormap(('red', 'green')))  
plt.xlim(x1.min(), x1.max())  
plt.ylim(x2.min(), x2.max())  
for i, j in enumerate(ny.unique(y_set)):  
    plt.scatter(x_set[y_set == j, 0], x_set[y_set == j, 1],  
        c = ListedColormap(('red', 'green'))(i), label = j)  
plt.title('SVM classifier (Training set)')  
plt.xlabel('Shots on Target')  
plt.ylabel('Key Passes')  
plt.legend()  
plt.show()
# Out:
# WARNING:matplotlib.axes._axes:*c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# WARNING:matplotlib.axes._axes:*c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %%
# Visulaizing the test set result  

from matplotlib.colors import ListedColormap  
x_set, y_set = x_test, y_test  
x1, x2 = ny.meshgrid(ny.arange(start = x_set[:, 0].min() - 1, stop = x_set[:, 0].max() + 1, step  =0.01),  
ny.arange(start = x_set[:, 1].min() - 1, stop = x_set[:, 1].max() + 1, step = 0.01)) 
plt.contourf(x1, x2, classifier.predict(ny.array([x1.ravel(), x2.ravel()]).T).reshape(x1.shape),  
alpha = 0.75, cmap = ListedColormap(('red','green' )))  
plt.xlim(x1.min(), x1.max())  
plt.ylim(x2.min(), x2.max())  
for i, j in enumerate(ny.unique(y_set)):  
    plt.scatter(x_set[y_set == j, 0], x_set[y_set == j, 1],  
        c = ListedColormap(('red', 'green'))(i), label = j)  
plt.title('SVM classifier (Test set)')  
plt.xlabel('Key Passes')  
plt.ylabel('Shots on Target')  
plt.legend()  
plt.show()
# Out:
# WARNING:matplotlib.axes._axes:*c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# WARNING:matplotlib.axes._axes:*c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %% [markdown]
# # Support vector classifier - Sigmoid

# %%
# Support vector classifier - Sigmoid

from sklearn.svm import SVC   
classifier = SVC(kernel='sigmoid', random_state=0)  
classifier.fit(x_train, y_train)
# Out:
# SVC(kernel='sigmoid', random_state=0)

# %%
# Predicting the test set result  

y_pred= classifier.predict(x_test)

# %%
# Creating the Confusion matrix

from sklearn.metrics import confusion_matrix  
cm= confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[88, 12],
#        [14, 27]])

# %%
from matplotlib.colors import ListedColormap  
x_set, y_set = x_train, y_train  
x1, x2 = ny.meshgrid(ny.arange(start = x_set[:, 0].min() - 1, stop = x_set[:, 0].max() + 1, step  =0.01), ny.arange(start = x_set[:, 1].min() - 1, stop = x_set[:, 1].max() + 1, step = 0.01))  
plt.contourf(x1, x2, classifier.predict(ny.array([x1.ravel(), x2.ravel()]).T).reshape(x1.shape), alpha = 0.75, cmap = ListedColormap(('red', 'green')))  
plt.xlim(x1.min(), x1.max())  
plt.ylim(x2.min(), x2.max())  
for i, j in enumerate(ny.unique(y_set)):  
    plt.scatter(x_set[y_set == j, 0], x_set[y_set == j, 1],  
        c = ListedColormap(('red', 'green'))(i), label = j)  
plt.title('SVM classifier (Training set)')  
plt.xlabel('Shots on Target')  
plt.ylabel('Key Passes')  
plt.legend()  
plt.show()
# Out:
# WARNING:matplotlib.axes._axes:*c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# WARNING:matplotlib.axes._axes:*c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %%
# Visulaizing the test set result  

from matplotlib.colors import ListedColormap  
x_set, y_set = x_test, y_test  
x1, x2 = ny.meshgrid(ny.arange(start = x_set[:, 0].min() - 1, stop = x_set[:, 0].max() + 1, step  =0.01),  
ny.arange(start = x_set[:, 1].min() - 1, stop = x_set[:, 1].max() + 1, step = 0.01)) 
plt.contourf(x1, x2, classifier.predict(ny.array([x1.ravel(), x2.ravel()]).T).reshape(x1.shape),  
alpha = 0.75, cmap = ListedColormap(('red','green' )))  
plt.xlim(x1.min(), x1.max())  
plt.ylim(x2.min(), x2.max())  
for i, j in enumerate(ny.unique(y_set)):  
    plt.scatter(x_set[y_set == j, 0], x_set[y_set == j, 1],  
        c = ListedColormap(('red', 'green'))(i), label = j)  
plt.title('SVM classifier (Test set)')  
plt.xlabel('Key Passes')  
plt.ylabel('Shots on Target')  
plt.legend()  
plt.show()
# Out:
# WARNING:matplotlib.axes._axes:*c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# WARNING:matplotlib.axes._axes:*c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %% [markdown]
# # Support vector classifier - rbf

# %%
# Support vector classifier - rbf

from sklearn.svm import SVC   
classifier = SVC(kernel='rbf', random_state=0)  
classifier.fit(x_train, y_train)
# Out:
# SVC(random_state=0)

# %%
# Predicting the test set result  

y_pred= classifier.predict(x_test)

# %%
# Creating the Confusion matrix

from sklearn.metrics import confusion_matrix  
cm= confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[91,  9],
#        [13, 28]])

# %%
from matplotlib.colors import ListedColormap  
x_set, y_set = x_train, y_train  
x1, x2 = ny.meshgrid(ny.arange(start = x_set[:, 0].min() - 1, stop = x_set[:, 0].max() + 1, step  =0.01), ny.arange(start = x_set[:, 1].min() - 1, stop = x_set[:, 1].max() + 1, step = 0.01))  
plt.contourf(x1, x2, classifier.predict(ny.array([x1.ravel(), x2.ravel()]).T).reshape(x1.shape), alpha = 0.75, cmap = ListedColormap(('red', 'green')))  
plt.xlim(x1.min(), x1.max())  
plt.ylim(x2.min(), x2.max())  
for i, j in enumerate(ny.unique(y_set)):  
    plt.scatter(x_set[y_set == j, 0], x_set[y_set == j, 1],  
        c = ListedColormap(('red', 'green'))(i), label = j)  
plt.title('SVM classifier (Training set)')  
plt.xlabel('Shots on Target')  
plt.ylabel('Key Passes')  
plt.legend()  
plt.show()
# Out:
# WARNING:matplotlib.axes._axes:*c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# WARNING:matplotlib.axes._axes:*c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %%
# Visulaizing the test set result  

from matplotlib.colors import ListedColormap  
x_set, y_set = x_test, y_test  
x1, x2 = ny.meshgrid(ny.arange(start = x_set[:, 0].min() - 1, stop = x_set[:, 0].max() + 1, step  =0.01),  
ny.arange(start = x_set[:, 1].min() - 1, stop = x_set[:, 1].max() + 1, step = 0.01)) 
plt.contourf(x1, x2, classifier.predict(ny.array([x1.ravel(), x2.ravel()]).T).reshape(x1.shape),  
alpha = 0.75, cmap = ListedColormap(('red','green' )))  
plt.xlim(x1.min(), x1.max())  
plt.ylim(x2.min(), x2.max())  
for i, j in enumerate(ny.unique(y_set)):  
    plt.scatter(x_set[y_set == j, 0], x_set[y_set == j, 1],  
        c = ListedColormap(('red', 'green'))(i), label = j)  
plt.title('SVM classifier (Test set)')  
plt.xlabel('Key Passes')  
plt.ylabel('Shots on Target')  
plt.legend()  
plt.show()
# Out:
# WARNING:matplotlib.axes._axes:*c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# WARNING:matplotlib.axes._axes:*c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %% [markdown]
# # Support vector classifier - poly

# %%
# Support vector classifier - rbf

from sklearn.svm import SVC   
classifier = SVC(kernel='poly', random_state=0)  
classifier.fit(x_train, y_train)
# Out:
# SVC(kernel='poly', random_state=0)

# %%
# Predicting the test set result  

y_pred= classifier.predict(x_test)

# %%
# Creating the Confusion matrix

from sklearn.metrics import confusion_matrix  
cm= confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[99,  1],
#        [25, 16]])

# %%
from matplotlib.colors import ListedColormap  
x_set, y_set = x_train, y_train  
x1, x2 = ny.meshgrid(ny.arange(start = x_set[:, 0].min() - 1, stop = x_set[:, 0].max() + 1, step  =0.01), ny.arange(start = x_set[:, 1].min() - 1, stop = x_set[:, 1].max() + 1, step = 0.01))  
plt.contourf(x1, x2, classifier.predict(ny.array([x1.ravel(), x2.ravel()]).T).reshape(x1.shape), alpha = 0.75, cmap = ListedColormap(('red', 'green')))  
plt.xlim(x1.min(), x1.max())  
plt.ylim(x2.min(), x2.max())  
for i, j in enumerate(ny.unique(y_set)):  
    plt.scatter(x_set[y_set == j, 0], x_set[y_set == j, 1],  
        c = ListedColormap(('red', 'green'))(i), label = j)  
plt.title('SVM classifier (Training set)')  
plt.xlabel('Shots on Target')  
plt.ylabel('Key Passes')  
plt.legend()  
plt.show()
# Out:
# WARNING:matplotlib.axes._axes:*c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# WARNING:matplotlib.axes._axes:*c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %%
# Visulaizing the test set result  

from matplotlib.colors import ListedColormap  
x_set, y_set = x_test, y_test  
x1, x2 = ny.meshgrid(ny.arange(start = x_set[:, 0].min() - 1, stop = x_set[:, 0].max() + 1, step  =0.01),  
ny.arange(start = x_set[:, 1].min() - 1, stop = x_set[:, 1].max() + 1, step = 0.01)) 
plt.contourf(x1, x2, classifier.predict(ny.array([x1.ravel(), x2.ravel()]).T).reshape(x1.shape),  
alpha = 0.75, cmap = ListedColormap(('red','green' )))  
plt.xlim(x1.min(), x1.max())  
plt.ylim(x2.min(), x2.max())  
for i, j in enumerate(ny.unique(y_set)):  
    plt.scatter(x_set[y_set == j, 0], x_set[y_set == j, 1],  
        c = ListedColormap(('red', 'green'))(i), label = j)  
plt.title('SVM classifier (Test set)')  
plt.xlabel('Key Passes')  
plt.ylabel('Shots on Target')  
plt.legend()  
plt.show()
# Out:
# WARNING:matplotlib.axes._axes:*c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# WARNING:matplotlib.axes._axes:*c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %% [markdown]
# # Regression SVM

# %%
# Reading the dataset

x = frames.iloc[:, 0:1].values
y = frames.iloc[:, 3].values
x

# %%
y = y.reshape(1, -1)

# %%
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
sc_y = StandardScaler()
x = sc_X.fit_transform(x)
y = sc_y.fit_transform(y)

# %%
from sklearn.svm import SVR
regressor = SVR(kernel = 'rbf')
regressor.fit(x_train, y_train)
# Out:
# SVR()

# %%
y = y.reshape(1, -1)
y_pred = y.reshape(1, -1)

# %%
y_pred = regressor.predict(4)
y_pred = sc_y.inverse_transform(y_pred)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-146-e4814a6447a8> in <module>
# ----> 1 y_pred = regressor.predict(4)
#       2 y_pred = sc_y.inverse_transform(y_pred)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py in predict(self, X)
#     412             The predicted values.
#     413         """
# --> 414         X = self._validate_for_predict(X)
#     415         predict = self._sparse_predict if self._sparse else self._dense_predict
#     416         return predict(X)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py in _validate_for_predict(self, X)
#     596                 order="C",
#     597                 accept_large_sparse=False,
# --> 598                 reset=False,
#     599             )
#     600
#
# ...

# %%
# Visualising the SVR results

X_grid = ny.arange(min(X), max(X), 0.01) #this step required because data is feature scaled.
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(x, y, color = 'red')
plt.plot(X_grid, regressor.predict(X_grid), color = 'blue')
plt.title('Truth or Bluff (SVR)')
plt.xlabel('Position level')
plt.ylabel('Salary')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-148-8be96e9008b4> in <module>
#       4 X_grid = X_grid.reshape((len(X_grid), 1))
#       5 plt.scatter(x, y, color = 'red')
# ----> 6 plt.plot(X_grid, regressor.predict(X_grid), color = 'blue')
#       7 plt.title('Truth or Bluff (SVR)')
#       8 plt.xlabel('Position level')
#
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py in predict(self, X)
#     412             The predicted values.
#     413         """
# --> 414         X = self._validate_for_predict(X)
#     415         predict = self._sparse_predict if self._sparse else self._dense_predict
#     416         return predict(X)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py in _validate_for_predict(self, X)
#     596                 order="C",
#     597                 accept_large_sparse=False,
# ...

# %% [markdown]
# # Practice

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-2f6b7b0f-945b-4488-a298-d87206a30ef8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2f6b7b0f-945b-4488-a298-d87206a30ef8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving isl_player_final.csv to isl_player_final (2).csv

# %%
df = pd.read_csv("isl_player_final.csv", header = None, usecols = [7, 21, 27, 34, 62] )
print(df)
df.columns = ['postion','events.goals', 'events.shots_on_target', 'events.offsides', 'touches.successful_tackles']
# Out:
#              7             21                      27               34  \
# 0      position  events.goals  events.shots_on_target  events.offsides
# 1       Forward             4                       9                6
# 2       Forward             3                       8                3
# 3       Forward             6                      10               20
# 4    Midfielder             1                       7                0
# ..          ...           ...                     ...              ...
# 559  Midfielder             2                       6                2
# 560    Defender             1                       3                0
# 561    Defender             1                       2                0
# 562  Midfielder             0                       0                0
# 563  Midfielder             0                       1                0
#
#                              62
# 0    touches.successful_tackles
# 1                             2
# ...

# %%
# import the MinyaxScaler class from the sklearn.neighbors library

from sklearn.preprocessing import MinyaxScaler

# %%
Scaling = MinyaxScaler()

# %%
Scaling.fit_transform(df[['events.shots_on_target', 'events.offsides']])
